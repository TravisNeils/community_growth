# %% [markdown]
# <a href="https://colab.research.google.com/github/TravisNeils/community_growth/blob/main/github_colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Header info

# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import numpy as np
import altair as alt

df = pd.DataFrame({'x': np.random.random(100),
              'y': np.random.random(100)})

alt.Chart(df).mark_point().encode(
    x = 'x:Q',
    y = 'y:Q'
)
# Out:
# alt.Chart(...)
